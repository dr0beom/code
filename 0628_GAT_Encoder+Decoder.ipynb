# %%
import torch
from torch import nn
import torch.nn.functional as F
import networkx as nx
import matplotlib.pyplot as plt
import torch.optim as optim
from scipy import sparse as sp
import random
from graphviz import Graph
import pickle
import numpy as np
import heapq

device = torch.device('cuda')

# %%
# Encoder
class GraphAttentionLayer(torch.nn.Module):
    def __init__(self, in_features, out_features, n_heads, is_concat = True, dropout = 0.6, leacky_relu_negative_slope = 0.2):
        super(GraphAttentionLayer, self).__init__()
        self.W = torch.nn.Parameter(torch.randn(in_features, out_features))
        self.is_concat = is_concat
        self.n_heads = n_heads

        if is_concat:
            assert out_features % n_heads == 0

            self.n_hidden = out_features // n_heads
        else:
            self.n_hidden = out_features

        self.linear = nn.Linear(in_features, self.n_hidden * n_heads, bias = False)

        self.attn = nn.Linear(self.n_hidden * 2, 1, bias = False)
        self.activation = nn.LeakyReLU(negative_slope = leacky_relu_negative_slope)
        self.softmax = nn.Softmax(dim=1)
        self.dropout = nn.Dropout(dropout) 

    def forward(self, x, adj):
        n_nodes = x.shape[0]
        g=self.linear(x).view(n_nodes, self.n_heads, self.n_hidden)
        g_repeat = g.repeat(n_nodes, 1,1)
        g_repeat_interleave = g.repeat_interleave(n_nodes, dim=0)
        g_concat = torch.cat([g_repeat_interleave, g_repeat], dim = -1)
        g_concat = g_concat.view(n_nodes, n_nodes, self.n_heads, 2 * self.n_hidden)
        e = self.activation(self.attn(g_concat))
        e = e.squeeze(-1)
        adj = adj.repeat(1, 1, self.n_heads)
        assert adj.shape[0] == 1 or adj.shape[0] == n_nodes
        assert adj.shape[1] == 1 or adj.shape[1] == n_nodes
        assert adj.shape[2] == 1 or adj.shape[2] == self.n_heads
        e=e.masked_fill(adj == 0, 1)
        a = self.softmax(e)
        a = self.dropout(a)
        attn_res = torch.einsum('ijh,jhf->ihf', a, g)
        if self.is_concat:
            return attn_res.reshape(n_nodes, self.n_heads * self.n_hidden)
        else:
            attn_res = attn_res.mean(dim=1)
            return attn_res

# %%
# Decoder
class Decoder(torch.nn.Module):
    def __init__(self, in_features, hidden_features, out_features, n_heads, d_h):
        super(Decoder, self).__init__()
        self.n_heads = n_heads
        self.hidden_features = hidden_features
        self.d_h = d_h
        self.in_features = in_features

        self.phi1 = torch.nn.Linear(d_h, 1)
        self.phi2 = torch.nn.Linear(d_h, 1)
        self.softmax = nn.Softmax(dim=1)
        self.C = torch.nn.Parameter(torch.randn(1)) # constant C
        self.activation = nn.Tanh()

    def forward(self, output, next_node, adj_matrix_original, next_nodes):
        v_i = output[next_node, 0]
        v_j = adj_matrix_original[next_node, :]
        v_j = v_j.unsqueeze(1).cuda() * output
        
        v_i = v_i.unsqueeze(0)
        phi1_v_i = torch.matmul(v_i, self.phi1.state_dict()['weight'])

        phi2_v_j = torch.matmul(v_j, self.phi2.state_dict()['weight'])

        attn_input = torch.matmul(phi1_v_i, phi2_v_j.transpose(0, 1)) / (self.d_h ** 0.5)

        attn_output = self.C * self.activation(attn_input)
        #???????????????
        # adj_matrix_original[row_indices, :] = 1
        # adj_matrix_original[np.logical_not(np.isin(np.arange(adj_matrix_original.shape[0]), row_indices)), :] = 0
        # print(adj_matrix_original[next_node,:])
        adj_matrix_original = torch.where(torch.tensor(np.isin(torch.arange(adj_matrix_original.shape[1]), next_nodes)), torch.tensor(0), adj_matrix_original)
        # print("adj_matrix_origianl[next_node,:] :", adj_matrix_original.to(device)[next_node,:])

        attn_output = attn_output * adj_matrix_original.to(device)[next_node, :]
        attn_output = attn_output.unsqueeze(0)

        attn_weights = self.softmax(attn_output)
        attn_weights *= (attn_output != 0).float()
        # print(attn_weights)

        p= torch.max(attn_weights)
        next_node = torch.argmax(attn_weights)

        return next_node, p

# %%
class GAT(torch.nn.Module):
    def __init__(self, in_features, hidden_features, out_features, n_heads, d_h):
        super(GAT, self).__init__()
        self.n_heads = n_heads
        self.attention1 = GraphAttentionLayer(in_features, hidden_features, n_heads, is_concat = True, dropout = dropout)
        self.attention2 = GraphAttentionLayer(hidden_features, out_features, 1, is_concat = False, dropout = dropout)
        self.norm= nn.LayerNorm(out_features)
        self.decoder = Decoder(in_features, hidden_features, out_features, n_heads, d_h)
    
    def forward(self, x, adj):
        x = self.attention1(x, adj)
        x = self.attention2(x, adj)
        x = self.norm(x)
        output = F.softmax(x, dim=0)
        output = torch.mean(output, dim=1)
        output = output.unsqueeze(0)
        output = output.transpose(0,1)
        return output
    
    def decode(self, output, i, adj_matrix_original, next_nodes):
        return self.decoder(output, i, adj_matrix_original, next_nodes)

# %%
in_features =  1
n_heads = 4

def generate_random_weighted_graph(num_nodes, num_edges, max_weight=10):
    # 방향 그래프 생성
    graph = nx.Graph()
    
    # 노드 추가
    nodes = range(num_nodes)
    graph.add_nodes_from(nodes)
    
    # 노드에 가중치 할당 및 노드 특징 벡터 생성
    x = torch.zeros(num_nodes, in_features)
    for node in graph.nodes:
        weight = random.randint(1, max_weight)
        graph.nodes[node]['weight'] = weight
        x[node] = weight

    # # 최소 하나의 에지를 가지도록 보장하기 위해 모든 노드에 대해 연결되지 않은 노드를 선택하여 에지를 추가합니다.
    # connected_nodes = set()
    # for node in nodes:
    #     if node not in connected_nodes:
    #         # 현재 노드와 연결되지 않은 노드 선택
    #         unconnected_nodes = list(set(nodes) - connected_nodes - {node})
    #         if len(unconnected_nodes) == 0 :
    #             break
    #         target = random.choice(unconnected_nodes)

    #         # 에지 추가
    #         graph.add_edge(node, target)
    #         connected_nodes.add(node)
    #         connected_nodes.add(target)

    # 모든 노드를 하나의 연결된 컴포넌트로 만들기 위해 하나의 노드를 선택하여 그 노드와 나머지 노드들을 연결합니다.
    connected_nodes = set()
    start_node = random.choice(nodes)
    connected_nodes.add(start_node)
    for node in nodes:
        if node != start_node:
            graph.add_edge(start_node, node)
            connected_nodes.add(node)

    # 추가적인 랜덤 에지를 생성하여 num_edges를 충족시킵니다.
    additional_edges = num_edges - len(graph.edges)
    for _ in range(additional_edges):
        # 임의의 출발 노드와 도착 노드 선택
        source = random.choice(nodes)
        target = random.choice(nodes)

        # 출발 노드와 도착 노드가 같은 경우나 이미 연결된 경우 건너뜁니다.
        if source == target or graph.has_edge(source, target):
            continue

        # 에지 추가
        graph.add_edge(source, target)

    graph_original = graph

        # Generate v_prev tensor
    j = random.randint(0, num_nodes-1)

    adj_matrix = nx.adjacency_matrix(graph)
    adj_matrix_original = torch.Tensor(adj_matrix.todense())
    
    adj_matrix = adj_matrix + sp.eye(adj_matrix.shape[0]) # Add self-loop
    adj_tensor = torch.Tensor(adj_matrix.todense())

    adj_tensor = adj_tensor.unsqueeze(2) # adj_tensor (num_nodes, num_nodes, n_heads)
    # adj_tensor = adj_tensor.repeat(1, 1, n_heads) #

    # # Visualize the graph
    # nx.draw_networkx(graph, with_labels=True)
    # plt.show()
    
    return graph, x, adj_tensor, adj_matrix_original, graph_original, j

# %%
num_graphs = 100
output_file = 'random_undirected_graphs.pkl'

graphs = []

for _ in range(num_graphs):
    m = np.random.randint(2,7)
    num_nodes, num_edges, max_weight = np.random.randint(m,8), np.random.randint(m+1,9), np.random.randint(1,30)
    graph, x, adj_tensor, adj_matrix_original, graph_original, j= generate_random_weighted_graph(num_nodes, num_edges, max_weight)
    next_nodes = []
    graphs.append((x, adj_tensor, j, adj_matrix_original, next_nodes))


# 그래프를 pickle 파일로 저장
with open(output_file, 'wb') as f:
    pickle.dump(graphs, f)
# Out:
# C:\Users\park\AppData\Local\Temp\ipykernel_7552\2839282210.py:62: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adj_matrix = nx.adjacency_matrix(graph)

# %%
# pickle 파일에서 그래프 데이터 로드
with open('random_undirected_graphs.pkl', 'rb') as f:
    graphs = pickle.load(f)

# %%
hidden_features = 4 * n_heads
out_features = n_heads
d_h = 4 * n_heads
dropout = 0.6
gat_model = GAT(in_features, hidden_features, out_features, n_heads, d_h).cuda()
gat_models = []
for graph_idx, (x, adj_tensor, j, adj_matrix_original, next_nodes) in enumerate(graphs):
    gat_models.append(gat_model)
    x = x.cuda()
    adj_tensor = adj_tensor.cuda()
    output = gat_model(x, adj_tensor)
    print(f"Graph {graph_idx+1} - Output:")
    print(output.shape)
    # print(output)
    n = output.size(0)
    next_nodes = [1] # next_node 값을 저장할 리스트
    branch_point = []
    row_indices = []
    possibilities=[]
    
    for i in range(n-1):
        next_node = next_nodes[i]
        row_indices = []
        row_indices = np.where(adj_matrix_original[:,next_node] == 1)[0]
        row_indices = np.setdiff1d(row_indices, next_nodes)
        # print("next_node", next_node)
        # print("next_nodes", next_nodes)
        # print("row_indices", row_indices)
        # print("!!", len(row_indices), type(row_indices))
        if len(row_indices) >= 2:
            branch_point.append(next_node)
            # print("branch_point has been updated")
        elif len(row_indices) == 0:
            if len(branch_point) > 0:
                next_node = branch_point.pop()
                # print("00000000000000000000",next_node)
                row_indices = np.where(np.isin(adj_matrix_original[:,next_node], next_nodes))[0]
                row_indices = np.setdiff1d(row_indices, next_nodes)
                # print("modified_row_indices:", row_indices)
                if len(row_indices) >= 2:
                    branch_point.append(next_node)
                    # print("22")
        
        next_node, p = gat_model.decode(output, next_node, adj_matrix_original, next_nodes)
        next_nodes.append(next_node.item())
        possibilities.append(p.item())
        # print("branch_point*******************************")
        # print(branch_point)

        print(f"Current Node: {next_nodes[i]}, Next Node: {next_nodes[i+1]}")
        


    print("Next Nodes:", next_nodes)
    print("")
    print("possibilities", possibilities)
    print("")
# Out:
# Graph 1 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 4, 0, 2, 3]
#
# possibilities [0.19950979948043823, 0.19983011484146118, 0.19968289136886597, 0.19939309358596802]
#
# Graph 2 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 0
# Next Nodes: [1, 4, 2, 5, 3, 0]
#
# possibilities [0.1666344851255417, 0.16657082736492157, 0.16650520265102386, 0.16643138229846954, 0.16631805896759033]
#
# Graph 3 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 6
# Current Node: 6, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 5
# Current Node: 5, Next Node: 3
# Next Nodes: [1, 2, 6, 4, 0, 5, 3]
#
# possibilities [0.14269335567951202, 0.14283311367034912, 0.1427982896566391, 0.14274416863918304, 0.14270778000354767, 0.14258328080177307]
#
# Graph 4 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 6
# Current Node: 6, Next Node: 3
# Next Nodes: [1, 0, 5, 2, 4, 6, 3]
#
# possibilities [0.14265033602714539, 0.14281117916107178, 0.14277932047843933, 0.1427432894706726, 0.14266440272331238, 0.1426078826189041]
#
# Graph 5 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 6
# Next Nodes: [1, 3, 2, 4, 5, 0, 6]
#
# possibilities [0.14266344904899597, 0.14267238974571228, 0.14277713000774384, 0.1427430361509323, 0.14271260797977448, 0.14264421164989471]
#
# Graph 6 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 2
# Next Nodes: [1, 0, 3, 2]
#
# possibilities [0.24968841671943665, 0.24937285482883453, 0.24905869364738464]
#
# Graph 7 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 6
# Current Node: 6, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 4
# Next Nodes: [1, 2, 0, 6, 3, 5, 4]
#
# possibilities [0.14267215132713318, 0.14280353486537933, 0.14277096092700958, 0.1427364945411682, 0.14269427955150604, 0.14263710379600525]
#
# Graph 8 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 6
# Current Node: 6, Next Node: 5
# Current Node: 5, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 0
# Next Nodes: [1, 6, 5, 4, 2, 3, 0]
#
# possibilities [0.14266690611839294, 0.14281435310840607, 0.14277759194374084, 0.1427338719367981, 0.14268715679645538, 0.14264962077140808]
#
# Graph 9 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 4
# Current Node: 4, Next Node: 2
# Next Nodes: [1, 0, 3, 4, 2]
#
# possibilities [0.19955849647521973, 0.19984112679958344, 0.19969066977500916, 0.19936500489711761]
#
# Graph 10 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 5, 3, 4, 0, 2]
#
# possibilities [0.1666470468044281, 0.16654610633850098, 0.16648390889167786, 0.16641689836978912, 0.16633976995944977]
#
# Graph 11 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 3, 2, 0, 4]
#
# possibilities [0.1995110958814621, 0.19979959726333618, 0.19968119263648987, 0.19942611455917358]
#
# Graph 12 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 5, 0, 4, 2, 3]
#
# possibilities [0.1666470766067505, 0.1665940135717392, 0.16652452945709229, 0.16639621555805206, 0.16625265777111053]
#
# Graph 13 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 6
# Current Node: 6, Next Node: 5
# Next Nodes: [1, 4, 0, 2, 3, 6, 5]
#
# possibilities [0.14265312254428864, 0.14279292523860931, 0.14275823533535004, 0.14271952211856842, 0.1426551789045334, 0.1426505297422409]
#
# Graph 14 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 2
# Next Nodes: [1, 0, 3, 2]
#
# possibilities [0.24977794289588928, 0.24938111007213593, 0.24902036786079407]
#
# Graph 15 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 4
# Current Node: 4, Next Node: 2
# Next Nodes: [1, 5, 0, 3, 4, 2]
#
# possibilities [0.16637443006038666, 0.1665610820055008, 0.16649888455867767, 0.16642449796199799, 0.1663372665643692]
#
# Graph 16 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 4
# Next Nodes: [1, 2, 0, 3, 4]
#
# possibilities [0.19945889711380005, 0.1998094916343689, 0.19960708916187286, 0.1994447112083435]
#
# Graph 17 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 5
# Next Nodes: [1, 4, 0, 2, 3, 5]
#
# possibilities [0.16663643717765808, 0.16657224297523499, 0.16636160016059875, 0.16630138456821442, 0.16637594997882843]
#
# Graph 18 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 5
# Next Nodes: [1, 0, 4, 2, 3, 5]
#
# possibilities [0.16662712395191193, 0.16657041013240814, 0.16651183366775513, 0.1664266139268875, 0.16633276641368866]
#
# Graph 19 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 3
# Next Nodes: [1, 0, 2, 4, 3]
#
# possibilities [0.1994485855102539, 0.19975736737251282, 0.199571892619133, 0.1994830071926117]
#
# Graph 20 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 2, 5, 3, 0, 4]
#
# possibilities [0.16638687252998352, 0.1665937453508377, 0.16652637720108032, 0.16646702587604523, 0.1662737876176834]
#
# Graph 21 - Output:
# torch.Size([2, 1])
# Current Node: 1, Next Node: 0
# Next Nodes: [1, 0]
#
# possibilities [0.4949783682823181]
#
# Graph 22 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 4, 3, 0, 2]
#
# possibilities [0.19967935979366302, 0.19956210255622864, 0.19963985681533813, 0.19935771822929382]
#
# Graph 23 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 3
# Next Nodes: [1, 2, 0, 3]
#
# possibilities [0.24975013732910156, 0.24918238818645477, 0.24910950660705566]
#
# Graph 24 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 6
# Next Nodes: [1, 2, 4, 3, 5, 0, 6]
#
# possibilities [0.14269064366817474, 0.14283744990825653, 0.1428072601556778, 0.1427638828754425, 0.14273598790168762, 0.14258846640586853]
#
# Graph 25 - Output:
# torch.Size([3, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 0, 2]
#
# possibilities [0.3323501646518707, 0.33135080337524414]
#
# Graph 26 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 0, 4, 2, 3]
#
# possibilities [0.19989560544490814, 0.1997709423303604, 0.19962424039840698, 0.1994476169347763]
#
# Graph 27 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 0
# Next Nodes: [1, 4, 3, 5, 2, 0]
#
# possibilities [0.16641342639923096, 0.16655826568603516, 0.16649304330348969, 0.1664290875196457, 0.16636058688163757]
#
# Graph 28 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 3, 2, 0, 4]
#
# possibilities [0.19950084388256073, 0.1997685730457306, 0.1996258646249771, 0.1993878036737442]
#
# Graph 29 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 6
# Current Node: 6, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 4
# Next Nodes: [1, 6, 0, 2, 5, 3, 4]
#
# possibilities [0.1426546573638916, 0.14279091358184814, 0.14275720715522766, 0.142722949385643, 0.1426876038312912, 0.14265286922454834]
#
# Graph 30 - Output:
# torch.Size([2, 1])
# Current Node: 1, Next Node: 0
# Next Nodes: [1, 0]
#
# possibilities [0.4949788451194763]
#
# Graph 31 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 6
# Next Nodes: [1, 4, 5, 3, 0, 2, 6]
#
# possibilities [0.14266236126422882, 0.14281044900417328, 0.14277546107769012, 0.1427392214536667, 0.14270690083503723, 0.14263217151165009]
#
# Graph 32 - Output:
# torch.Size([3, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 0, 2]
#
# possibilities [0.3322974741458893, 0.33152857422828674]
#
# Graph 33 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 0, 2, 3]
#
# possibilities [0.24977435171604156, 0.2491491138935089, 0.24899441003799438]
#
# Graph 34 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 3
# Next Nodes: [1, 0, 5, 2, 4, 3]
#
# possibilities [0.1666010171175003, 0.16652709245681763, 0.16645447909832, 0.1663738340139389, 0.16637414693832397]
#
# Graph 35 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 4
# Current Node: 4, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 0, 4, 5, 2, 3]
#
# possibilities [0.16661670804023743, 0.16642799973487854, 0.1664026826620102, 0.16638533771038055, 0.16626474261283875]
#
# Graph 36 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 6
# Current Node: 6, Next Node: 0
# Next Nodes: [1, 5, 2, 4, 3, 6, 0]
#
# possibilities [0.1426646113395691, 0.1428220570087433, 0.14279046654701233, 0.14268961548805237, 0.1427236944437027, 0.1425776481628418]
#
# Graph 37 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 3, 4, 0, 2]
#
# possibilities [0.19965235888957977, 0.19977857172489166, 0.19943946599960327, 0.19943106174468994]
#
# Graph 38 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 0, 2, 3]
#
# possibilities [0.249388188123703, 0.24941933155059814, 0.24905981123447418]
#
# Graph 39 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 6
# Current Node: 6, Next Node: 0
# Next Nodes: [1, 5, 2, 4, 3, 6, 0]
#
# possibilities [0.14265909790992737, 0.14283040165901184, 0.14279110729694366, 0.14274604618549347, 0.1427137404680252, 0.14264099299907684]
#
# Graph 40 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 6
# Current Node: 6, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Current Node: 4, Next Node: 5
# Next Nodes: [1, 6, 3, 2, 0, 4, 5]
#
# possibilities [0.14267180860042572, 0.14280563592910767, 0.14277437329292297, 0.14274311065673828, 0.14270785450935364, 0.14261455833911896]
#
# Graph 41 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 2
# Next Nodes: [1, 0, 3, 2]
#
# possibilities [0.2497851848602295, 0.24950511753559113, 0.2489631175994873]
#
# Graph 42 - Output:
# torch.Size([3, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 0
# Next Nodes: [1, 2, 0]
#
# possibilities [0.3325290381908417, 0.33127835392951965]
#
# Graph 43 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 6
# Current Node: 6, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 5
# Next Nodes: [1, 4, 6, 3, 0, 2, 5]
#
# possibilities [0.14258448779582977, 0.1428070217370987, 0.1427779346704483, 0.14275039732456207, 0.14272062480449677, 0.14268863201141357]
#
# Graph 44 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Current Node: 4, Next Node: 3
# Next Nodes: [1, 2, 0, 4, 3]
#
# possibilities [0.19973446428775787, 0.19954107701778412, 0.19963859021663666, 0.19951647520065308]
#
# Graph 45 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 4
# Next Nodes: [1, 0, 2, 3, 4]
#
# possibilities [0.19950087368488312, 0.19975954294204712, 0.19961439073085785, 0.19947978854179382]
#
# Graph 46 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 6
# Current Node: 6, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 5
# Next Nodes: [1, 6, 4, 3, 2, 0, 5]
#
# possibilities [0.14267179369926453, 0.14280825853347778, 0.14267559349536896, 0.14274202287197113, 0.1426953226327896, 0.14263691008090973]
#
# Graph 47 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 3
# Next Nodes: [1, 2, 4, 0, 3]
#
# possibilities [0.19995546340942383, 0.19954177737236023, 0.19965267181396484, 0.19937297701835632]
#
# Graph 48 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 3
# Next Nodes: [1, 0, 2, 4, 3]
#
# possibilities [0.19948187470436096, 0.19976384937763214, 0.19964176416397095, 0.19947774708271027]
#
# Graph 49 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 6
# Current Node: 6, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 5
# Next Nodes: [1, 4, 6, 2, 0, 3, 5]
#
# possibilities [0.1426047533750534, 0.1428062468767166, 0.1427772045135498, 0.14274661242961884, 0.1426830142736435, 0.1426723152399063]
#
# Graph 50 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 4, 3, 0, 2]
#
# possibilities [0.19946646690368652, 0.19975623488426208, 0.19958814978599548, 0.19947946071624756]
#
# Graph 51 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 5
# Current Node: 5, Next Node: 6
# Current Node: 6, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 4
# Next Nodes: [1, 0, 5, 6, 3, 2, 4]
#
# possibilities [0.14268764853477478, 0.14282557368278503, 0.14279736578464508, 0.14275434613227844, 0.1427224725484848, 0.1425957828760147]
#
# Graph 52 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 4
# Next Nodes: [1, 0, 3, 2, 4]
#
# possibilities [0.19969873130321503, 0.1995064616203308, 0.19957943260669708, 0.1994129717350006]
#
# Graph 53 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 6
# Next Nodes: [1, 5, 0, 3, 2, 4, 6]
#
# possibilities [0.14282813668251038, 0.14279450476169586, 0.1427610069513321, 0.14272676408290863, 0.14268288016319275, 0.14264775812625885]
#
# Graph 54 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 5
# Current Node: 5, Next Node: 4
# Current Node: 4, Next Node: 6
# Next Nodes: [1, 3, 2, 0, 5, 4, 6]
#
# possibilities [0.14266043901443481, 0.1427958756685257, 0.14276036620140076, 0.1427226960659027, 0.14268676936626434, 0.1426486223936081]
#
# Graph 55 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 6
# Current Node: 6, Next Node: 2
# Next Nodes: [1, 5, 4, 3, 0, 6, 2]
#
# possibilities [0.14272597432136536, 0.14266334474086761, 0.14276234805583954, 0.14272618293762207, 0.1426926553249359, 0.14265166223049164]
#
# Graph 56 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 3, 2, 5, 0, 4]
#
# possibilities [0.16650505363941193, 0.1663927435874939, 0.16652144491672516, 0.16644597053527832, 0.16630803048610687]
#
# Graph 57 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 3
# Next Nodes: [1, 4, 0, 2, 5, 3]
#
# possibilities [0.1663993000984192, 0.1665850728750229, 0.1665286123752594, 0.16640618443489075, 0.1662604808807373]
#
# Graph 58 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 2
# Next Nodes: [1, 0, 3, 2]
#
# possibilities [0.24939168989658356, 0.24905942380428314, 0.24903829395771027]
#
# Graph 59 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 6
# Current Node: 6, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 4
# Next Nodes: [1, 6, 5, 0, 3, 2, 4]
#
# possibilities [0.14260362088680267, 0.1428060233592987, 0.14276176691055298, 0.14271150529384613, 0.14267182350158691, 0.14258696138858795]
#
# Graph 60 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Next Nodes: [1, 5, 4, 3, 2, 0]
#
# possibilities [0.1666269302368164, 0.16638118028640747, 0.16651204228401184, 0.16641569137573242, 0.16635148227214813]
#
# Graph 61 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 5, 3, 2, 0, 4]
#
# possibilities [0.16662907600402832, 0.1665656864643097, 0.16649894416332245, 0.16638562083244324, 0.1663065105676651]
#
# Graph 62 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 6
# Current Node: 6, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 5, 3, 6, 2, 0, 4]
#
# possibilities [0.14261803030967712, 0.14278727769851685, 0.14274756610393524, 0.14270292222499847, 0.1426631063222885, 0.14262385666370392]
#
# Graph 63 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 4
# Current Node: 4, Next Node: 0
# Next Nodes: [1, 2, 3, 5, 4, 0]
#
# possibilities [0.16644303500652313, 0.16649533808231354, 0.166378453373909, 0.1664510816335678, 0.16630074381828308]
#
# Graph 64 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 4
# Next Nodes: [1, 0, 3, 5, 2, 4]
#
# possibilities [0.16634948551654816, 0.16657263040542603, 0.16637052595615387, 0.16643981635570526, 0.1663358211517334]
#
# Graph 65 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 0
# Current Node: 0, Next Node: 5
# Current Node: 5, Next Node: 3
# Next Nodes: [1, 2, 4, 0, 5, 3]
#
# possibilities [0.16631782054901123, 0.16657660901546478, 0.16649901866912842, 0.16643837094306946, 0.16635119915008545]
#
# Graph 66 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 5
# Current Node: 5, Next Node: 4
# Next Nodes: [1, 3, 2, 0, 5, 4]
#
# possibilities [0.1664654016494751, 0.16635747253894806, 0.1664794683456421, 0.1663476526737213, 0.1663159281015396]
#
# Graph 67 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 6
# Current Node: 6, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 0
# Next Nodes: [1, 6, 4, 3, 5, 2, 0]
#
# possibilities [0.14270952343940735, 0.1428137719631195, 0.14278335869312286, 0.1426168531179428, 0.1427140235900879, 0.14266425371170044]
#
# Graph 68 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Current Node: 4, Next Node: 5
# Current Node: 5, Next Node: 6
# Next Nodes: [1, 3, 2, 0, 4, 5, 6]
#
# possibilities [0.1426699459552765, 0.14280153810977936, 0.1427626609802246, 0.14272481203079224, 0.1426910012960434, 0.14265426993370056]
#
# Graph 69 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 6
# Current Node: 6, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 4, 5, 0, 6, 2, 3]
#
# possibilities [0.1426870971918106, 0.14281877875328064, 0.14278221130371094, 0.14274083077907562, 0.1427062600851059, 0.1426311433315277]
#
# Graph 70 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 6
# Current Node: 6, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 3, 5, 6, 2, 0, 4]
#
# possibilities [0.14264866709709167, 0.1427943855524063, 0.14275798201560974, 0.1427200883626938, 0.14268110692501068, 0.14261586964130402]
#
# Graph 71 - Output:
# torch.Size([3, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 0, 2]
#
# possibilities [0.33255502581596375, 0.33125925064086914]
#
# Graph 72 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 4
# Next Nodes: [1, 0, 2, 3, 4]
#
# possibilities [0.19990482926368713, 0.1997729390859604, 0.19962410628795624, 0.1994553804397583]
#
# Graph 73 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 4
# Current Node: 4, Next Node: 6
# Current Node: 6, Next Node: 0
# Next Nodes: [1, 3, 2, 5, 4, 6, 0]
#
# possibilities [0.14283934235572815, 0.14280831813812256, 0.14277631044387817, 0.1427118182182312, 0.14261245727539062, 0.14267420768737793]
#
# Graph 74 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 3
# Next Nodes: [1, 2, 0, 3]
#
# possibilities [0.24941274523735046, 0.2489205151796341, 0.2490839660167694]
#
# Graph 75 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 6
# Current Node: 6, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 4
# Next Nodes: [1, 6, 0, 3, 5, 2, 4]
#
# possibilities [0.14268915355205536, 0.14282222092151642, 0.14279372990131378, 0.14275743067264557, 0.14272534847259521, 0.14258858561515808]
#
# Graph 76 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 0
# Next Nodes: [1, 4, 3, 2, 5, 0]
#
# possibilities [0.16642767190933228, 0.16654647886753082, 0.16648489236831665, 0.16642245650291443, 0.16635525226593018]
#
# Graph 77 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 3, 5, 2, 0, 4]
#
# possibilities [0.16633766889572144, 0.16655130684375763, 0.16636492311954498, 0.16640637814998627, 0.16633927822113037]
#
# Graph 78 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 5
# Current Node: 5, Next Node: 4
# Current Node: 4, Next Node: 2
# Next Nodes: [1, 3, 0, 5, 4, 2]
#
# possibilities [0.16636641323566437, 0.1665714532136917, 0.16637586057186127, 0.16645991802215576, 0.1663372665643692]
#
# Graph 79 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 0, 2, 3]
#
# possibilities [0.24903032183647156, 0.24936586618423462, 0.24909473955631256]
#
# Graph 80 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 4
# Next Nodes: [1, 2, 5, 0, 3, 4]
#
# possibilities [0.16636593639850616, 0.16657009720802307, 0.16649989783763885, 0.16642916202545166, 0.16631586849689484]
#
# Graph 81 - Output:
# torch.Size([3, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 0, 2]
#
# possibilities [0.3323119282722473, 0.33129677176475525]
#
# Graph 82 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 6
# Next Nodes: [1, 3, 5, 0, 2, 4, 6]
#
# possibilities [0.14265860617160797, 0.14279824495315552, 0.14276371896266937, 0.14265860617160797, 0.1426917016506195, 0.14264513552188873]
#
# Graph 83 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 4
# Current Node: 4, Next Node: 0
# Next Nodes: [1, 5, 2, 3, 4, 0]
#
# possibilities [0.16627345979213715, 0.16652822494506836, 0.16645516455173492, 0.16637066006660461, 0.16628457605838776]
#
# Graph 84 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 6
# Current Node: 6, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 4
# Current Node: 4, Next Node: 5
# Next Nodes: [1, 0, 6, 2, 3, 4, 5]
#
# possibilities [0.14261551201343536, 0.14277809858322144, 0.14267578721046448, 0.14267241954803467, 0.14265505969524384, 0.1426113098859787]
#
# Graph 85 - Output:
# torch.Size([2, 1])
# Current Node: 1, Next Node: 0
# Next Nodes: [1, 0]
#
# possibilities [0.49497464299201965]
#
# Graph 86 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 3
# Next Nodes: [1, 2, 4, 5, 0, 3]
#
# possibilities [0.16642218828201294, 0.16656066477298737, 0.16637256741523743, 0.16644233465194702, 0.16636304557323456]
#
# Graph 87 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 6
# Current Node: 6, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 0
# Next Nodes: [1, 4, 2, 6, 5, 3, 0]
#
# possibilities [0.14261247217655182, 0.14281436800956726, 0.14278073608875275, 0.1427430808544159, 0.14266473054885864, 0.14267398416996002]
#
# Graph 88 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 0
# Next Nodes: [1, 4, 3, 2, 5, 0]
#
# possibilities [0.166471928358078, 0.16640596091747284, 0.16654793918132782, 0.16641418635845184, 0.16623787581920624]
#
# Graph 89 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 0, 2, 3]
#
# possibilities [0.24943684041500092, 0.24942930042743683, 0.24900098145008087]
#
# Graph 90 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 3, 0, 2]
#
# possibilities [0.2497393786907196, 0.24939945340156555, 0.24901072680950165]
#
# Graph 91 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 3
# Current Node: 3, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 2, 3, 0, 4]
#
# possibilities [0.1995583474636078, 0.1994902491569519, 0.19966931641101837, 0.19950290024280548]
#
# Graph 92 - Output:
# torch.Size([4, 1])
# Current Node: 1, Next Node: 0
# Current Node: 0, Next Node: 2
# Current Node: 2, Next Node: 3
# Next Nodes: [1, 0, 2, 3]
#
# possibilities [0.24946649372577667, 0.2491627186536789, 0.24899019300937653]
#
# Graph 93 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 3
# Current Node: 3, Next Node: 4
# Next Nodes: [1, 5, 2, 0, 3, 4]
#
# possibilities [0.16637293994426727, 0.16657376289367676, 0.1665157824754715, 0.16645941138267517, 0.16631007194519043]
#
# Graph 94 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 4
# Next Nodes: [1, 3, 2, 0, 4]
#
# possibilities [0.19949008524417877, 0.19975630939006805, 0.19962817430496216, 0.19947147369384766]
#
# Graph 95 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 0
# Current Node: 0, Next Node: 2
# Next Nodes: [1, 4, 3, 5, 0, 2]
#
# possibilities [0.16663673520088196, 0.16639433801174164, 0.16650496423244476, 0.16644251346588135, 0.16632524132728577]
#
# Graph 96 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 3
# Current Node: 3, Next Node: 5
# Current Node: 5, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 0
# Next Nodes: [1, 3, 5, 4, 2, 0]
#
# possibilities [0.16662850975990295, 0.16657234728336334, 0.16651614010334015, 0.16645698249340057, 0.16629958152770996]
#
# Graph 97 - Output:
# torch.Size([7, 1])
# Current Node: 1, Next Node: 6
# Current Node: 6, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 5
# Current Node: 5, Next Node: 3
# Current Node: 3, Next Node: 0
# Next Nodes: [1, 6, 4, 2, 5, 3, 0]
#
# possibilities [0.14265896379947662, 0.14281761646270752, 0.14275039732456207, 0.14271004498004913, 0.142670139670372, 0.14259818196296692]
#
# Graph 98 - Output:
# torch.Size([5, 1])
# Current Node: 1, Next Node: 4
# Current Node: 4, Next Node: 2
# Current Node: 2, Next Node: 0
# Current Node: 0, Next Node: 3
# Next Nodes: [1, 4, 2, 0, 3]
#
# possibilities [0.19951625168323517, 0.19976122677326202, 0.19962768256664276, 0.19947293400764465]
#
# Graph 99 - Output:
# torch.Size([3, 1])
# Current Node: 1, Next Node: 2
# Current Node: 2, Next Node: 0
# Next Nodes: [1, 2, 0]
#
# possibilities [0.3326280117034912, 0.3313620388507843]
#
# Graph 100 - Output:
# torch.Size([6, 1])
# Current Node: 1, Next Node: 5
# Current Node: 5, Next Node: 2
# Current Node: 2, Next Node: 4
# Current Node: 4, Next Node: 3
# Current Node: 3, Next Node: 0
# Next Nodes: [1, 5, 2, 4, 3, 0]
#
# possibilities [0.16666100919246674, 0.16631300747394562, 0.16622398793697357, 0.16647394001483917, 0.16640238463878632]

# %% [markdown]
# 참고
# https://chioni.github.io/posts/gat/
